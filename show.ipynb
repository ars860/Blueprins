# %%
import torch

from dataset import get_dataloaders_supervised
from iou import iou_global
from plot_samples import plot_first_ten
from unet import Unet

device = 'cuda'
model = Unet(layers=[8, 16, 32, 64, 128], output_channels=11).to(device)

_, dataloader_train, _, dataloader_test = get_dataloaders_supervised()

def plot_shit(model_name):
    model.load_state_dict(torch.load(model_name, map_location=device))

    plot_first_ten(model, dataloader_train, 'show', device=device)

# %%
plot_shit('learned_models/without_transfer/200epochs_1e-5.pt')

# %%
from iou import iou_global

iou_global(dataloader=dataloader_train, model=model, device=device)
# Out:
# array([0.47105828, 0.65508374, 0.81839664, 0.61659058, 0.763849  ,
#        0.86702872, 0.78624171, 0.88367599, 0.90978143, 0.88940343,
#        0.78461957])

# %%
iou_global(dataloader_test, model, device)
# Out:
# array([0.15752252, 0.25208463, 0.24848868, 0.45236514, 0.29258179,
#        0.38193883, 0.33976619, 0.42853093, 0.61111111, 0.3398153 ,
#        0.61111117])

# %%
plot_shit('learned_models/logged_100epochs.pt')
